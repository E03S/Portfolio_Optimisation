# %%
from yahoo_parser import SP500Parser
from datetime import datetime, date

# %%
parser = SP500Parser()

# %%
parser.save_sp500_tickers()

# %%
start_date = datetime(2008, 1, 1)
end_date = date.today()

df = parser.download_sp500_data(start_date=start_date,
                                end_date=end_date)
# Out:
# [*********************100%%**********************]  503 of 503 completed
# 2 Failed downloads:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2008-01-01 00:00:00 -> 2023-10-31)')

# %%
parser.save_data_to_csv('data/snp500_stocks_from_2008.csv')

# %%
df[df['Symbol'] == "AAPL"]['High'].plot()
# Out:
# <Axes: xlabel='Date'>
