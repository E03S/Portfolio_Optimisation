# %%
import pandas as pd
import zipfile

# %%
df = pd.read_csv('../../datasets/news_sp_500.csv')

# %%
examples_df = df.head()

# %%
    # end date in the same format
examples_df['created'] = pd.to_datetime(examples_df['created'])
examples_df.head()
# Out:
# /var/folders/8v/ps3k66h11hjf_56rkxfbt3tm0000gn/T/ipykernel_22265/3442698806.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   examples_df['created'] = pd.to_datetime(examples_df['created'])
#    Unnamed: 0.1  Unnamed: 0        id    author                   created  \
# 0             0         0.0  457336.0  Benzinga 2010-09-03 13:33:35-04:00
# 1             1         1.0  457416.0  Benzinga 2010-09-03 14:20:38-04:00
# 2             2         2.0  457794.0  Benzinga 2010-09-03 19:19:40-04:00
# 3             3         3.0  458028.0  Benzinga 2010-09-05 06:33:25-04:00
# 4             4         4.0  458346.0  Benzinga 2010-09-06 11:09:10-04:00
#
#                            updated  \
# 0  Fri, 03 Sep 2010 13:33:35 -0400
# 1  Fri, 03 Sep 2010 14:37:03 -0400
# 2  Fri, 03 Sep 2010 19:19:40 -0400
# 3  Sun, 05 Sep 2010 06:33:26 -0400
# 4  Mon, 06 Sep 2010 11:09:10 -0400
#
#                                                title teaser  \
# 0     Digital River Extends MSFT Deal - Analyst Blog    NaN
# 1  Google Celebrates Chrome Anniversary With Vers...    NaN
# 2  Fast Money Picks For September 7th (HRB, JOYG,...    NaN
# 3            Dell Aims to Secure SMBs - Analyst Blog    NaN
# 4        Autodesk Unveils AutoCAD Mac - Analyst Blog    NaN
#
#                                                 body  \
# 0  \nIn a recent filing with the Securities and E...
# 1  While Google (NASDAQ: GOOG) may be a powerhous...
# 2  CNBC's Fast Money Steve Grasso said on the sho...
# 3  \nRound Rock Texas-based PC maker Dell Inc. (D...
# 4  \nAutodesk Inc. (ADSK) announced to launch a M...
#
#                                     url image  \
# 0  https://www.benzinga.com/node/457336    []
# 1  https://www.benzinga.com/node/457416    []
# 2  https://www.benzinga.com/node/457794    []
# 3  https://www.benzinga.com/node/458028    []
# 4  https://www.benzinga.com/node/458346    []
#
#                                             channels  \
# 0                                                 []
# 1  [{'name': 'News'}, {'name': 'Management'}, {'n...
# 2  [{'name': 'CNBC'}, {'name': 'Long Ideas'}, {'n...
# 3                                                 []
# 4                                                 []
#
#                                               stocks  \
# 0               [{'name': 'DRIV'}, {'name': 'MSFT'}]
# 1  [{'name': 'AAPL'}, {'name': 'GOOG'}, {'name': ...
# 2  [{'name': 'CTXS'}, {'name': 'FNSR'}, {'name': ...
# 3  [{'name': 'AAPL'}, {'name': 'DELL'}, {'name': ...
# 4  [{'name': 'AAPL'}, {'name': 'ADSK'}, {'name': ...
#
#                                                 tags
# 0  [{'name': 'Information Technology'}, {'name': ...
# 1                         [{'name': 'Engadget.com'}]
# 2  [{'name': 'Application Software'}, {'name': 'C...
# 3  [{'name': 'Communications Equipment'}, {'name'...
# 4  [{'name': 'Application Software'}, {'name': 'C...

# %%
start_date = '2010-09-02'  # start date in the format Year-Month-Day
end_date = '2010-09-04'
mask = (examples_df['created'] >= start_date) & (examples_df['created'] <= end_date)
filtered_df = examples_df.loc[mask]
filtered_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        id    author                   created  \
# 0             0         0.0  457336.0  Benzinga 2010-09-03 13:33:35-04:00
# 1             1         1.0  457416.0  Benzinga 2010-09-03 14:20:38-04:00
# 2             2         2.0  457794.0  Benzinga 2010-09-03 19:19:40-04:00
#
#                            updated  \
# 0  Fri, 03 Sep 2010 13:33:35 -0400
# 1  Fri, 03 Sep 2010 14:37:03 -0400
# 2  Fri, 03 Sep 2010 19:19:40 -0400
#
#                                                title teaser  \
# 0     Digital River Extends MSFT Deal - Analyst Blog    NaN
# 1  Google Celebrates Chrome Anniversary With Vers...    NaN
# 2  Fast Money Picks For September 7th (HRB, JOYG,...    NaN
#
#                                                 body  \
# 0  \nIn a recent filing with the Securities and E...
# 1  While Google (NASDAQ: GOOG) may be a powerhous...
# 2  CNBC's Fast Money Steve Grasso said on the sho...
#
#                                     url image  \
# 0  https://www.benzinga.com/node/457336    []
# 1  https://www.benzinga.com/node/457416    []
# 2  https://www.benzinga.com/node/457794    []
#
#                                             channels  \
# 0                                                 []
# 1  [{'name': 'News'}, {'name': 'Management'}, {'n...
# 2  [{'name': 'CNBC'}, {'name': 'Long Ideas'}, {'n...
#
#                                               stocks  \
# 0               [{'name': 'DRIV'}, {'name': 'MSFT'}]
# 1  [{'name': 'AAPL'}, {'name': 'GOOG'}, {'name': ...
# 2  [{'name': 'CTXS'}, {'name': 'FNSR'}, {'name': ...
#
#                                                 tags
# 0  [{'name': 'Information Technology'}, {'name': ...
# 1                         [{'name': 'Engadget.com'}]
# 2  [{'name': 'Application Software'}, {'name': 'C...

# %%
df['created'] = pd.to_datetime(df['created'], errors='coerce')
df = df.dropna(subset=['created'])

# %%
df.sort_values(by=['created'], inplace=True, ascending=True)
df.head()
# Out:
#         Unnamed: 0.1  Unnamed: 0     id    author                   created  \
# 212687        212687       696.0  244.0  Benzinga 2009-07-27 08:38:00-04:00
# 2108            2108      2107.0  196.0  Benzinga 2009-07-27 09:22:00-04:00
# 49216          49216      6516.0  192.0  Benzinga 2009-07-27 09:33:00-04:00
# 18280          18280      1348.0  191.0  Benzinga 2009-07-27 09:38:00-04:00
# 2107            2107      2106.0  186.0  Benzinga 2009-07-27 09:47:00-04:00
#
#                                 updated  \
# 212687  Tue, 26 Jun 2012 20:42:12 -0400
# 2108    Tue, 26 Jun 2012 20:38:47 -0400
# 49216   Tue, 26 Jun 2012 20:38:27 -0400
# 18280   Tue, 26 Jun 2012 20:38:22 -0400
# 2107    Tue, 26 Jun 2012 20:37:59 -0400
#
#                                                     title  \
# 212687  Wall Street News Alert:  Ahead of the Bell: Pe...
# 2108    Stocks to Watch for Monday, July 27, 2009: CSE...
# 49216   Wall Street News Alert: Stock Alert: GSAE -- J...
# 18280   Wall Street News Alert: Hot Stock to Watch for...
# 2107    "Stock Alerts" Capitalize on Volatile Markets ...
#
#                                                    teaser  \
# 212687  WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 2108    ATLANTA, GA--(Marketwire - July 27, 2009) -  M...
# 49216   WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 18280   WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 2107    SANTA CLARA, CA--(Marketwire - July 27, 2009) ...
#
#                                                      body  \
# 212687  WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 2108    ATLANTA, GA--(Marketwire - July 27, 2009) -  M...
# 49216   WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 18280   WESTON, FL--(Marketwire - July 27, 2009) -  Wa...
# 2107    SANTA CLARA, CA--(Marketwire - July 27, 2009) ...
#
#                                                       url image channels  \
# 212687  https://www.benzinga.com/09/07/244/wall-street...    []       []
# 2108    https://www.benzinga.com/09/07/196/stocks-to-w...    []       []
# 49216   https://www.benzinga.com/09/07/192/wall-street...    []       []
# 18280   https://www.benzinga.com/09/07/191/wall-street...    []       []
# 2107    https://www.benzinga.com/09/07/186/stock-alert...    []       []
#
#                                                    stocks  \
# 212687  [{'name': 'BIDU'}, {'name': 'LVS'}, {'name': '...
# 2108                 [{'name': 'AAPL'}, {'name': 'MSFT'}]
# 49216   [{'name': 'AAPL'}, {'name': 'COF'}, {'name': '...
# 18280   [{'name': 'AMZN'}, {'name': 'SPWRA'}, {'name':...
# 2107    [{'name': 'CIT'}, {'name': 'CME'}, {'name': 'I...
#
#                                                      tags
# 212687  [{'name': 'Casinos & Gaming'}, {'name': 'Consu...
# 2108                                                   []
# 49216                                                  []
# 18280                                                  []
# 2107                                                   []

# %%
# 2009-07-27 08:38:00-04:00
# 2023-10-30 14:20:03-04:00
df.set_index('created', inplace=True)

# %%
weekly_data = {}
import ast
import itertools
from textblob import TextBlob

def extract_names(row):
    if pd.isna(row):
        return []
    dict_list = ast.literal_eval(row)
    return [d['name'] for d in dict_list]

def concatenate_list_of_list(lol):
    return list(itertools.chain.from_iterable(lol))

def tokenize_and_contatenate(list_of_text):
    # print(list_of_text)
    return ' '.join([' '.join(TextBlob(str(text)).words) for text in list_of_text])
for period_start, group in df.resample('W'):
    index = period_start.strftime('%Y-%m-%d')
    period_object = {
        'body': tokenize_and_contatenate(group['body'].tolist()),
        'title': tokenize_and_contatenate(group['title'].tolist()),
        'stocks': set(concatenate_list_of_list(group['stocks'].apply(extract_names).tolist()))
    }
    weekly_data[index] = period_object

# %%
weekly_data.keys()
# Out:
# dict_keys(['2009-08-02', '2009-08-09', '2009-08-16', '2009-08-23', '2009-08-30', '2009-09-06', '2009-09-13', '2009-09-20', '2009-09-27', '2009-10-04', '2009-10-11', '2009-10-18', '2009-10-25', '2009-11-01', '2009-11-08', '2009-11-15', '2009-11-22', '2009-11-29', '2009-12-06', '2009-12-13', '2009-12-20', '2009-12-27', '2010-01-03', '2010-01-10', '2010-01-17', '2010-01-24', '2010-01-31', '2010-02-07', '2010-02-14', '2010-02-21', '2010-02-28', '2010-03-07', '2010-03-14', '2010-03-21', '2010-03-28', '2010-04-04', '2010-04-11', '2010-04-18', '2010-04-25', '2010-05-02', '2010-05-09', '2010-05-16', '2010-05-23', '2010-05-30', '2010-06-06', '2010-06-13', '2010-06-20', '2010-06-27', '2010-07-04', '2010-07-11', '2010-07-18', '2010-07-25', '2010-08-01', '2010-08-08', '2010-08-15', '2010-08-22', '2010-08-29', '2010-09-05', '2010-09-12', '2010-09-19', '2010-09-26', '2010-10-03', '2010-10-10', '2010-10-17', '2010-10-24', '2010-10-31', '2010-11-07', '2010-11-14', '2010-11-21', '2010-11-28', '2010-
#  'title': 'Wall Street News Alert Ahead of the Bell Petroleum Consolidators of America July 27 2009 Stocks to Watch for Monday July 27 2009 CSEV ONE Holdings Acquires Green Planet and Forecasting 2009 Revenue EBITDA and Net Income of 13.5 Million 6.9 Million and 4.8 Million Respectively Wall Street News Alert Stock Alert GSAE July 27 2009 Wall Street News Alert Hot Stock to Watch for Monday PCAI July 27 2009 Stock Alerts Capitalize on Volatile Markets With 95 Profitable Trades New Cisco Data Center Capabilities Help to Secure Data and Improve Disaster Recovery GE and Plutonic Power Granted Court Approval for Extension of Due-Diligence Period for Dokie Wind Project Acquisition',
#  'stocks': {'AAPL',
#   'AMZN',
#   'BIDU',
#   'CIT',
#   'CME',
#   'COF',
#   'CSCO',
#   'GE',
#   'ISRG',
#   'LVS',
#   'MSFT',
#   'PFE',
#   'SPWRA',
#   'TXN',
#   'VZ'}}

# %%
items = weekly_data.items()
keys_to_delete = []
for key, value in items:
    if not value['title']:
        keys_to_delete.append(key)

for key in keys_to_delete:
    del weekly_data[key]

# %%
df_merged = pd.DataFrame.from_dict(weekly_data, orient='index')
df_merged.head()
# Out:
#                                                          body  \
# 2009-08-02  WESTON FL Marketwire July 27 2009 Wall Street ...
# 2009-08-09  MONTREAL QUEBEC Marketwire Aug 6 2009 Cosmos C...
# 2009-08-16  FREMONT CA Marketwire August 10 2009 Optichron...
# 2009-10-11  Carl Icahn on a CNBC interview this morning st...
# 2009-10-25  Carl Icahn activist investor and one of Yahoo ...
#
#                                                         title  \
# 2009-08-02  Wall Street News Alert Ahead of the Bell Petro...
# 2009-08-09  Cosmos Group Requests Access to Cossette 's Bo...
# 2009-08-16  Optichron R Second-Generation Digital Pre-Dist...
# 2009-10-11  Carl Icahn Warns Of Bloodbath For Many Investo...
# 2009-10-25        Carl Icahn Resigns From Yahoo 's Board YHOO
#
#                                                        stocks
# 2009-08-02  {LVS, CME, VZ, AAPL, MSFT, TXN, CIT, GE, PFE, ...
# 2009-08-09  {AM, VIA, PPY, CML, PM, SE, AGX, CI, PLL, ADG,...
# 2009-08-16  {NRC, CML, PM, WR, CAG, SE, LG, NG, CNA, CRE, ...
# 2009-10-11                            {VNQ, GOOG, MSFT, YHOO}
# 2009-10-25                                       {YHOO, MSFT}

# %%
df_merged.to_csv('../../datasets/news_sp_500_weekly.csv')

# %%
df_merged['title'].apply(lambda x: len(x)).describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_merged['title'].apply(lambda x: len(x)).describe()
#
# NameError: name 'df_merged' is not defined

# %%
df_merged = pd.read_csv('../../datasets/news_sp_500_weekly.csv')

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")

encoding = tiktoken.encoding_for_model("gpt-4-1106-preview")
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

df_merged['body'].apply(lambda x: num_tokens_from_string(x, "cl100k_base")).describe()
# Out:
# count       724.000000
# mean     137189.063536
# std      100552.495463
# min         153.000000
# 25%       69974.500000
# 50%       95241.000000
# 75%      184510.750000
# max      769017.000000
# Name: body, dtype: float64

# %%
df_merged['title'].apply(lambda x: num_tokens_from_string(x, "cl100k_base")).describe()
# Out:
# count      724.000000
# mean      7236.482044
# std       4387.362228
# min          5.000000
# 25%       4189.750000
# 50%       6313.500000
# 75%       9448.250000
# max      23260.000000
# Name: title, dtype: float64
