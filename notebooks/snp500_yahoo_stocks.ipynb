# %%
import os
import sys
from datetime import datetime

project_root = os.path.abspath('..')
sys.path.insert(0, project_root)

from src.data.yahoo_parser import SP500Parser

# %%
parser = SP500Parser()

# %%
parser.save_sp500_tickers()

# %%
start_date = datetime(2023, 10, 1)
end_date = datetime.now()

df = parser.download_sp500_data(start_date=start_date,
                                end_date=end_date)
# Out:
# [*********************100%%**********************]  503 of 503 completed
# 2 Failed downloads:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-01 00:00:00 -> 2023-10-31 15:11:14.866934)')

# %%
df.head()
# Out:
#            Symbol   Adj Close       Close        High         Low        Open  \
# Date
# 2023-10-02      A  110.900002  110.900002  111.800003  109.769997  110.900002
# 2023-10-03      A  110.260002  110.260002  111.760002  110.050003  110.230003
# 2023-10-04      A  111.669998  111.669998  111.889999  109.379997  110.410004
# 2023-10-05      A  110.349998  110.349998  112.239998  108.769997  112.089996
# 2023-10-06      A  110.639999  110.639999  111.769997  109.360001  109.489998
#
#                Volume
# Date
# 2023-10-02  1569000.0
# 2023-10-03  1543400.0
# 2023-10-04  1541700.0
# 2023-10-05  1295700.0
# 2023-10-06  1796100.0

# %%
parser.save_data_to_csv('../data/raw/snp500_stocks_example.csv')

# %%
df[df['Symbol'] == "AAPL"]
# Out:
#            Symbol   Adj Close       Close        High         Low        Open  \
# Date
# 2023-10-02   AAPL  173.750000  173.750000  174.300003  170.929993  171.220001
# 2023-10-03   AAPL  172.399994  172.399994  173.630005  170.820007  172.259995
# 2023-10-04   AAPL  173.660004  173.660004  174.210007  170.970001  171.089996
# 2023-10-05   AAPL  174.910004  174.910004  175.449997  172.679993  173.789993
# 2023-10-06   AAPL  177.490005  177.490005  177.990005  173.179993  173.800003
# 2023-10-09   AAPL  178.990005  178.990005  179.050003  175.800003  176.809998
# 2023-10-10   AAPL  178.389999  178.389999  179.720001  177.949997  178.100006
# 2023-10-11   AAPL  179.800003  179.800003  179.850006  177.600006  178.199997
# 2023-10-12   AAPL  180.710007  180.710007  182.339996  179.039993  180.070007
# 2023-10-13   AAPL  178.850006  178.850006  181.929993  178.139999  181.419998
# 2023-10-16   AAPL  178.720001  178.720001  179.080002  176.509995  176.750000
# ...

# %%
df[df['Symbol'] == "AAPL"]['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
